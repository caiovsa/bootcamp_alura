# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Aula 01

# %%
fonte = "https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A151346189_28_143_208.csv"

data = pd.read_csv(fonte, encoding = "ISO-8859-1" , skiprows = 3,sep = ";", skipfooter = 12, thousands = ".", decimal = ",")
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#fonte2 = "A151346189_28_143_208.csv"

#data2 = pd.read_csv(fonte2, encoding = "ISO-8859-1" , skiprows = 3,sep = ";", skipfooter = 12, thousands = ".", decimal = ",")

# %%
data
# Out:
#       Unidade da Federação     2008/Jan      2008/Fev      2008/Mar  \
# 0              11 Rondônia   1388528.39  2.931283e+06  1.541683e+06
# 1                  12 Acre    902416.00  1.497206e+06  1.794028e+06
# 2              13 Amazonas   4735529.42  7.118991e+06  8.196635e+06
# 3               14 Roraima    657889.53  7.779393e+05  7.186880e+05
# 4                  15 Pará  18864744.11  1.955376e+07  2.193734e+07
# 5                 16 Amapá   1120973.34  1.268740e+06  9.746512e+05
# 6             17 Tocantins   3441592.69  4.985689e+06  6.205613e+06
# 7              21 Maranhão  10723506.39  1.355968e+07  1.398514e+07
# 8                 22 Piauí   7985142.43  1.007993e+07  1.029837e+07
# 9                 23 Ceará  15539821.90  2.573510e+07  2.872463e+07
# 10  24 Rio Grande do Norte   5947814.08  9.509756e+06  1.035224e+07
# 11              25 Paraíba  10723002.45  1.138627e+07  1.205364e+07
# 12           26 Pernambuco  14393949.89  2.418140e+07  2.999130e+07
# ...

# %%
data.shape
# Out:
# (27, 154)

# %%
data.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2019/Dez     2020/Jan     2020/Fev     2020/Mar     2020/Abr  \
# ...

# %%
data.tail()
# Out:
#      Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 22   43 Rio Grande do Sul  30931325.46  57363420.01  51547794.07  56673338.49
# 23  50 Mato Grosso do Sul   5377392.11   7002472.61   8423933.19   8797487.68
# 24         51 Mato Grosso   4795299.01   8684882.23   7886243.14   8794109.79
# 25               52 Goiás  15310637.29  22258668.68  21442515.75  20921212.45
# 26    53 Distrito Federal   4745919.19   7632480.67   9647203.26  11098732.99
#
#        2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 22  48397733.07  52413429.62  56636376.98  56113054.70  55356224.30  ...
# 23   9770421.80  10905392.18  10249299.82   9671553.45  10218511.05  ...
# 24   9231645.40  10221763.77   9163314.28   9243148.81   9052354.89  ...
# 25  21615970.67  18270043.87  20540517.13  20650730.67  20868443.56  ...
# 26  12891719.72  12850125.67  12565646.74  13710857.89  13165106.20  ...
#
# ...

# %%
data.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Abr    4.101366e+07
# 2020/Mai    4.419363e+07
# 2020/Jun    4.732999e+07
# 2020/Jul    5.449551e+07
# Total       5.993732e+09
# Length: 151, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(151), object(3)
# memory usage: 32.6+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
data.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
data["2008/Ago"]
# Out:
# 0      3231494.61
# 1      2089107.14
# 2      9352532.70
# 3       894271.18
# 4     23341218.03
# 5      1475551.38
# 6      5413710.38
# 7     15195312.89
# 8     10549176.40
# 9     27851438.72
# 10    10640817.47
# 11    12872578.37
# 12    35457038.66
# 13     9373432.00
# 14     5238398.50
# 15    46931248.28
# 16    84722528.10
# 17    12588595.77
# 18    50912706.60
# 19   184854516.35
# 20    56982774.90
# 21    31250854.33
# 22    56113054.70
# 23     9671553.45
# 24     9243148.81
# 25    20650730.67
# 26    13710857.89
# Name: 2008/Ago, dtype: float64

# %%
data["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
data.plot(x = "Unidade da Federação", y = "2008/Ago")
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
#plt.figure(figsize = (16,9))
import matplotlib.ticker as ticker

ax = data.plot(x = "Unidade da Federação", y = "2008/Ago", kind = "bar", figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor dos gastos por Unidade da Federação em Agosto de 2008")
plt.xlabel("Estado")
plt.ylabel("Valor gasto")
# Out:
# Text(0, 0.5, 'Valor gasto')

# %%
ax = data.plot(x = "Unidade da Federação", y = "2020/Jul", kind = "bar", figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor dos gastos por Unidade da Federação em Julho de 2020")
plt.xlabel("Estado")
plt.ylabel("Valor gasto")
# Out:
# Text(0, 0.5, 'Valor gasto')

# %%
data["2020/Ago"]
# Out:
# 0      10285455.78
# 1                -
# 2      14726443.67
# 3       2826486.18
# 4      39911193.02
# 5       2942273.94
# 6       8240261.38
# 7      28587541.78
# 8      23210624.20
# 9      59808605.59
# 10     24929930.72
# 11     22130016.81
# 12     75704177.72
# 13     19754741.78
# 14     11014180.89
# 15     80793117.08
# 16    168024412.95
# 17     32188873.88
# 18     95274486.35
# 19    346512263.17
# 20    129375911.54
# 21     63972379.36
# 22    101374341.51
# 23     19241624.02
# 24     17790649.87
# 25     43984702.05
# 26     26526196.39
# Name: 2020/Ago, dtype: object

# %%
# Troquei o - que existia antes
data['2020/Ago'] = data['2020/Ago'].replace(['-'],0)

# %%
# Agora vou mudar os valores de Agosto que estão como objeto, para Float
data['2020/Ago'] = pd.to_numeric(data["2020/Ago"])

# %%
data["2020/Ago"]
# Out:
# 0     10285455.78
# 1            0.00
# 2     14726443.67
# 3      2826486.18
# 4     39911193.02
# 5      2942273.94
# 6      8240261.38
# 7     28587541.78
# 8     23210624.20
# 9     59808605.59
# 10    24929930.72
# 11    22130016.81
# 12    75704177.72
# 13    19754741.78
# 14    11014180.89
# 15    80793117.08
# 16   168024412.95
# 17    32188873.88
# 18    95274486.35
# 19   346512263.17
# 20   129375911.54
# 21    63972379.36
# 22   101374341.51
# 23    19241624.02
# 24    17790649.87
# 25    43984702.05
# 26    26526196.39
# Name: 2020/Ago, dtype: float64

# %%
ax = data.plot(x = "Unidade da Federação", y = "2020/Ago", kind = "bar", figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# Detalhes do grafico
plt.title("Valor dos gastos Hospitalares por Unidade da Federação em Agosto de 2020")
plt.grid()
plt.xlabel("Estados")
plt.ylabel("Valor gasto (R$)")

# Download da figura
plt.savefig('Desafio_1.png', dpi=300, bbox_inches='tight', facecolor="white")
plt.show()

# %% [markdown]
# # Aula 02

# %%
fonte2 = "https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv"

data2 = pd.read_csv(fonte2, encoding="ISO-8859-1", skiprows = 3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data2.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2019/Dez    2020/Jan    2020/Fev  \
# 0        -        -        -  ...  8660753.05  8326416.32  8413784.42
# 1        -        -        -  ...  2959569.09  3261123.88  2981264.22
# 2        -        -        -  ... 14923380.22 15939561.23 15138110.70
# 3        -        -        -  ...  2889969.87  3084561.08  2967159.04
# 4        -        -        -  ... 35222625.80 37009819.17 34635702.52
#
#      2020/Mar    2020/Abr    2020/Mai    2020/Jun    2020/Jul     2020/Ago  \
# ...

# %%
data2.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
data2.shape
# Out:
# (27, 280)

# %%
data2[["2008/Ago","2008/Set"]]
# Out:
#        2008/Ago     2008/Set
# 0    2938286.29   2843930.91
# 1    1886871.84   2084884.80
# 2    8331763.97   8148089.92
# 3    1045291.11   1003740.89
# 4   23259148.28  23667690.01
# 5    1550340.63   1550166.99
# 6    5213290.38   5201400.94
# 7   14609872.57  15317881.85
# 8   10645917.52  11037940.55
# 9   29304821.51  30435026.82
# 10  10812840.19  11258681.53
# 11  12673774.35  12790639.17
# 12  31705296.79  30703879.20
# 13   9262767.68   9228201.96
# 14   4543252.50   4525676.82
# 15  43254543.33  42851268.02
# 16  80374117.08  82400146.79
# 17  12384068.19  12486952.61
# 18  42487939.51  43066461.47
# 19 179898070.22 180082203.71
# 20  56699001.13  58091985.79
# 21  28887854.62  30725718.78
# 22  56233758.74  57910170.98
# 23   9602843.49  10272466.74
# 24   8987811.95   8843061.60
# 25  21041071.33  21396098.51
# 26  11548451.89  12422577.60

# %%
colunas_usaveis = data2.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
data_usavel = data2[colunas_usaveis]
data_usavel.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2019/Nov  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  8948605.66
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3174249.43
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 14781332.42
# 3   808448.39   771687.83   876091.18   896952.53  ...  3121104.71
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 35555518.00
#
#      2019/Dez    2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai  \
# ...

# %%
data_usavel = data_usavel.set_index("Unidade da Federação")
data_usavel.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
data_usavel["2019/Ago"]
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374191.37
# 22 Piauí                  17816404.11
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073307.72
# 25 Paraíba                19854699.54
# 26 Pernambuco             71735626.96
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77852441.31
# 31 Minas Gerais          161707825.05
# 32 Espírito Santo         29298721.79
# 33 Rio de Janeiro         83311603.59
# 35 São Paulo             302367276.77
# 41 Paraná                127174095.05
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98546110.10
# 50 Mato Grosso do Sul     19217982.14
# ...

# %%
data_usavel.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
data_usavel.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
data_usavel = data_usavel.drop("Total", axis = 1)

# %%
data_usavel.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
data_usavel.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %% [markdown]
# ### Desafio 01, posição da legenda
# ### https://bit.ly/3jZToPg

# %%
# Creio eu que o desafio 1 eu resolvi ali com o plt.legend

ax = data_usavel.T.plot(figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1, 1), loc = "upper left")
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
data_usavel2 = data_usavel.loc[["28 Sergipe","35 São Paulo","29 Bahia","33 Rio de Janeiro","42 Santa Catarina"]]

# %%
data_usavel2.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 28 Sergipe             27453.63   78565.19   122952.94   775705.52
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 29 Bahia              135146.36  448349.75  1382038.11  3348779.62
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
# 42 Santa Catarina     693955.05 1092964.12  3562300.82  7578502.38
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 28 Sergipe            2765495.63    5439985.99   4636850.76   5017838.07
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# 29 Bahia             11948984.56   73336297.08  33410124.06  41301703.40
# 33 Rio de Janeiro    13627123.27  250564959.99  44122593.19  42892665.52
# 42 Santa Catarina    14772555.10   53034384.67  24409572.92  27483480.50
#
# ...

# %%
data_usavel2.T.head()
# Out:
# Unidade da Federação  28 Sergipe  35 São Paulo    29 Bahia  33 Rio de Janeiro  \
# 2007/Ago                27453.63    1665349.90   135146.36          469469.34
# 2007/Set                78565.19    4434168.64   448349.75          921646.57
# 2007/Out               122952.94   14577395.84  1382038.11         2994664.57
# 2007/Nov               775705.52   35032259.98  3348779.62         7250528.08
# 2007/Dez              2765495.63   76668547.41 11948984.56        13627123.27
#
# Unidade da Federação  42 Santa Catarina
# 2007/Ago                      693955.05
# 2007/Set                     1092964.12
# 2007/Out                     3562300.82
# 2007/Nov                     7578502.38
# 2007/Dez                    14772555.10

# %%
# Forma 1 do desafio 2
ax = data_usavel.T[["28 Sergipe","35 São Paulo","29 Bahia","33 Rio de Janeiro","42 Santa Catarina"]].plot(figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(0.9, 0.85), bbox_transform=plt.gcf().transFigure)
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
# Forma 2 do desafio 2

ax = data_usavel2.T.plot(figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(0.9, 0.85), bbox_transform=plt.gcf().transFigure)
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# # Aula 03

# %%
print (plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# Creio eu que o desafio 1 eu resolvi ali com o plt.legend

ax = data_usavel.T.plot(figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1, 1), loc = "upper left")
#plt.style.use('default')
plt.show()
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
data_usavel.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
data_usavel.T.index[:5]
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez'], dtype='object')

# %%
data_usavel.T[:5]
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
# Forma 3 do desafio 2
ax = data_usavel[:5].T.plot(figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(0.9, 0.85), bbox_transform=plt.gcf().transFigure)
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
import numpy as np

# Vou criar com o numpy um random seed, ou seja, pra reproduzir um sample aleatorio, mas que seja reproduzido  de forma "igual" quando eu rodar o codigo novamente
# Muda de celula pra celula no jupyter notebook

np.random.seed(687942)
data_usavel.sample(n=7)
# Out:
#                         2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 32 Espírito Santo       57408.11  284224.80  1152115.25  2296383.23
# 31 Minas Gerais        971394.37 2861781.50 10018011.35 21730281.63
# 24 Rio Grande do Norte 134605.36  272088.08   684678.30  1695824.89
# 17 Tocantins             4113.76   76633.06   343702.61  1068685.94
# 53 Distrito Federal    191951.47  769966.25  2165619.56  3813256.48
# 50 Mato Grosso do Sul  199556.12  573675.41  1069816.66  1995899.52
# 16 Amapá                33672.74  104822.98   118378.28   226661.18
#
#                           2007/Dez     2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 32 Espírito Santo       5724199.54  16212109.41 10032886.43 12262049.08
# 31 Minas Gerais        43429517.54 205912743.65 70301089.50 79119005.51
# 24 Rio Grande do Norte  4730811.68  11763899.23  9110108.87 10126626.54
# 17 Tocantins            3022200.87   5136474.61  5051932.07  5200151.87
# ...

# %%
# Da pra notar que ele é diferente da celula de cima, e fica mudando, teria que criar outra seed aqui
data_usavel.sample(n=7)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 42 Santa Catarina     693955.05 1092964.12  3562300.82  7578502.38
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 21 Maranhão           385330.18 1018352.93  2277717.78  4334468.23
# 52 Goiás              179395.82  418053.58  1198730.25  2712117.54
# 32 Espírito Santo      57408.11  284224.80  1152115.25  2296383.23
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 42 Santa Catarina    14772555.10   53034384.67  24409572.92  27483480.50
# 33 Rio de Janeiro    13627123.27  250564959.99  44122593.19  42892665.52
# 31 Minas Gerais      43429517.54  205912743.65  70301089.50  79119005.51
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# ...

# %%
# Esse aqui é a outra seed
np.random.seed(6879)
data_usavel.sample(n=7)
# Out:
#                        2007/Ago   2007/Set   2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 25 Paraíba             97352.78  368130.43 1002088.64  2149873.40  5448177.36
# 42 Santa Catarina     693955.05 1092964.12 3562300.82  7578502.38 14772555.10
# 11 Rondônia             4209.37   16397.03  133645.19   346912.84   711758.31
# 23 Ceará              357904.65  572356.18 1865065.71  5131814.39 10798042.86
# 50 Mato Grosso do Sul 199556.12  573675.41 1069816.66  1995899.52  4277979.14
# 16 Amapá               33672.74  104822.98  118378.28   226661.18   844019.90
# 41 Paraná             554800.22 1431708.01 4630402.44 11120030.79 28790722.87
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 25 Paraíba            16599004.84 10871589.62 12348758.14 12680965.13
# 42 Santa Catarina     53034384.67 24409572.92 27483480.50 27806641.44
# 11 Rondônia            1829559.71  1940792.63  1955721.68  2143353.81
# ...

# %%
data_usavel["Total"] = data_usavel.sum(axis = 1)
data_usavel.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
data_usavel.sum(axis = 1).sort_values()
# Out:
# Unidade da Federação
# 16 Amapá                   581563399.44
# 14 Roraima                 606971982.90
# 12 Acre                    841333511.62
# 11 Rondônia               1851145347.64
# 17 Tocantins              1995014482.70
# 28 Sergipe                2257170646.18
# 13 Amazonas               3533851108.18
# 51 Mato Grosso            4061479652.28
# 27 Alagoas                4195806848.08
# 22 Piauí                  4245352414.58
# 50 Mato Grosso do Sul     4336178076.48
# 53 Distrito Federal       4835548680.46
# 25 Paraíba                4923883317.26
# 24 Rio Grande do Norte    4938471532.78
# 32 Espírito Santo         6256706399.38
# 21 Maranhão               7243770211.20
# 15 Pará                   8851074961.14
# 52 Goiás                  9274078111.20
# 23 Ceará                 12365572804.08
# 42 Santa Catarina        14613939419.02
# 26 Pernambuco            16026270211.54
# 29 Bahia                 18335467382.42
# 33 Rio de Janeiro        19319876014.24
# ...

# %% [markdown]
# ## Desafio, coluna mostrando a região por estado

# %%
Norte = ["Norte"]*7
Nordeste = ["Nordeste"]*9
Centro = ["Centro-Oeste"]*3
Sudeste = ["Sudeste"]*4
Sul = ["Sul"]*3
DF = ["Centro-Oeste"]

tudao = Norte + Nordeste + Centro + Sudeste + Sul + DF
tudao2 = ["Norte"]*7 + ["Nordeste"]*9 + ["Centro-Oeste"]*3 + ["Sudeste"]*4 + ["Sul"]*3 + ["Centro-Oeste"]
m = np.asarray(tudao)
print(m)
print(tudao2)
# Out:
# ['Norte' 'Norte' 'Norte' 'Norte' 'Norte' 'Norte' 'Norte' 'Nordeste'
#  'Nordeste' 'Nordeste' 'Nordeste' 'Nordeste' 'Nordeste' 'Nordeste'
#  'Nordeste' 'Nordeste' 'Centro-Oeste' 'Centro-Oeste' 'Centro-Oeste'
#  'Sudeste' 'Sudeste' 'Sudeste' 'Sudeste' 'Sul' 'Sul' 'Sul' 'Centro-Oeste']
# ['Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Centro-Oeste', 'Centro-Oeste', 'Centro-Oeste', 'Sudeste', 'Sudeste', 'Sudeste', 'Sudeste', 'Sul', 'Sul', 'Sul', 'Centro-Oeste']

# %%
#data_usavel["Região"] = ['Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte','Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste','Centro-Oeste', 'Centro-Oeste', 'Centro-Oeste', 'Centro-Oeste','Sudeste', 'Sudeste', 'Sudeste', 'Sudeste','Sul', 'Sul', 'Centro-Oeste']

# %%
data_usavel["Região"] = tudao

# %%
data_usavel
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# 22 Piauí                220788.25  353468.67  1078182.68  2406035.32
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 25 Paraíba               97352.78  368130.43  1002088.64  2149873.40
# ...

# %% [markdown]
# # Desafio meu
# ### Ver o gasto por região

# %%
data_usavel.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
data_usavel.T.tail()
# Out:
# Unidade da Federação  11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2020/Mai               8581195.13   2383895.48   19441150.53   2910776.44
# 2020/Jun               9193593.76   2199920.70   17509334.66   3216466.51
# 2020/Jul               7407388.24   1163813.08   13358514.02   2739498.41
# Total                925572673.82 420666755.81 1766925554.09 303485991.45
# Região                      Norte        Norte         Norte        Norte
#
# Unidade da Federação       15 Pará     16 Amapá 17 Tocantins   21 Maranhão  \
# 2020/Mai               41248502.78   2701014.87   6732370.56   32979447.97
# 2020/Jun               35396030.78   2699492.23   5018138.13   31128144.66
# 2020/Jul               27618727.51   2155083.37   4489665.87   24374205.15
# Total                4425537480.57 290781699.72 997507241.35 3621885105.60
# Região                       Norte        Norte        Norte      Nordeste
#
# ...

# %%
tentativa = data_usavel.groupby(['Região']).sum()
tentativa = tentativa.drop("Total", axis = 1)
tentativa.head()
# Out:
#                2007/Ago    2007/Set    2007/Out    2007/Nov     2007/Dez  \
# Região
# Centro-Oeste 1690223.29  4837619.12 16330410.73 35090449.42  69902805.77
# Nordeste     1863465.81  4373676.55 11981822.18 27667726.92  68937797.91
# Norte         274163.86   702698.79  3034989.40  9438700.38  24930500.29
# Sudeste      3963357.50 10141753.91 31341411.21 70323225.95 150366081.08
# Sul           442514.44  1224173.61  3195766.50  6448456.66  18966119.35
#
#                   2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# Região
# Centro-Oeste  483250898.51 134672525.92 145901638.37 148717767.61
# Nordeste      240233627.20 143170221.70 163986250.16 169546980.47
# Norte          44017418.18  38844188.02  42058042.63  43806481.51
# Sudeste      1185744863.36 291997238.93 306505817.05 306172479.98
# Sul            90578272.96  34358557.99  40202469.49  39437608.08
#
#                  2008/Mai  ...     2019/Out     2019/Nov     2019/Dez  \
# Região                     ...
# ...

# %%
# Forma 3 do desafio 2
ax = tentativa.T.plot(figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
#plt.legend(bbox_to_anchor=(0.9, 0.85), bbox_transform=plt.gcf().transFigure)

plt.xlabel("Região do Brasil")
plt.ylabel("Gastos em R$")
plt.title("Valor dos gastos Hospitalares por Região")
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0.5, 1.0, 'Valor dos gastos Hospitalares por Região')

# %%
tentativa2 = data_usavel.groupby(['Região']).mean()
tentativa2 = tentativa2.drop("Total", axis = 1)
tentativa2.head()
# Out:
#               2007/Ago   2007/Set   2007/Out    2007/Nov    2007/Dez  \
# Região
# Centro-Oeste 422555.82 1209404.78 4082602.68  8772612.35 17475701.44
# Nordeste     207051.76  485964.06 1331313.58  3074191.88  7659755.32
# Norte         39166.27  100385.54  433569.91  1348385.77  3561500.04
# Sudeste      990839.38 2535438.48 7835352.80 17580806.49 37591520.27
# Sul          147504.81  408057.87 1065255.50  2149485.55  6322039.78
#
#                  2008/Jan    2008/Fev    2008/Mar    2008/Abr    2008/Mai  \
# Região
# Centro-Oeste 120812724.63 33668131.48 36475409.59 37179441.90 36727505.67
# Nordeste      26692625.24 15907802.41 18220694.46 18838553.39 18808783.83
# Norte          6288202.60  5549169.72  6008291.80  6258068.79  6461605.85
# Sudeste      296436215.84 72999309.73 76626454.26 76543119.99 77002660.71
# Sul           30192757.65 11452852.66 13400823.16 13145869.36 12794284.21
#
#               ...     2019/Out     2019/Nov     2019/Dez     2020/Jan  \
# ...

# %%
# Forma 3 do desafio 2
ax = tentativa2.T.plot(figsize = (16,9))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
#plt.legend(bbox_to_anchor=(0.9, 0.85), bbox_transform=plt.gcf().transFigure)

plt.xlabel("Região do Brasil")
plt.ylabel("Gastos em R$")
plt.title("Valor da média dos gastos Hospitalares por Região")
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Text(0.5, 1.0, 'Valor da média dos gastos Hospitalares por Região')

# %%
data_usavel.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
ordenado_total = data_usavel.sort_values("Total", ascending = False)
ordenado_total = ordenado_total.drop("Total", axis = 1)
ordenado_total = ordenado_total.drop("Região", axis = 1)
ordenado_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# 31 Minas Gerais      43429517.54  205912743.65  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  250564959.99  44122593.19  42892665.52
#
# ...

# %%
ordenado_total.T["28 Sergipe"]
# Out:
# 2007/Ago     27453.63
# 2007/Set     78565.19
# 2007/Out    122952.94
# 2007/Nov    775705.52
# 2007/Dez   2765495.63
#               ...
# 2020/Mar   9193248.73
# 2020/Abr   8395906.57
# 2020/Mai   8450209.57
# 2020/Jun   6705923.03
# 2020/Jul   3312766.32
# Name: 28 Sergipe, Length: 156, dtype: float64

# %%
ax = ordenado_total.head().T.plot(figsize = (16,9))
#ax = ordenado_total..plot(figsize = (16,9))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.xlabel("Região do Brasil")
plt.ylabel("Gastos em R$")
plt.title("Estados com maior gasto Hospitalar")

plt.show()
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
# DESAFIO DO GRAFIO COM MAIORES E SERGIPE

ax = ordenado_total.T[["35 São Paulo","31 Minas Gerais","41 Paraná","43 Rio Grande do Sul","33 Rio de Janeiro","28 Sergipe"]].plot(figsize = (16,9))
#ax = ordenado_total.T["28 Sergipe"].plot(figsize = (16,9))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.xlabel("Região do Brasil")
plt.ylabel("Gastos em R$")
plt.title("Estados com maior gasto Hospitalar e SERGIPE")

plt.show()
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# ### Elimeni aquele pico

# %%
colunas_quero = ordenado_total.columns[6:]
ordenado_total2 = ordenado_total[colunas_quero]
ordenado_total2.T.head()
# Out:
# Unidade da Federação  35 São Paulo  31 Minas Gerais   41 Paraná  \
# 2008/Fev              172834914.73      70301089.50 48855046.46
# 2008/Mar              170481849.56      79119005.51 55611791.07
# 2008/Abr              170278285.95      79046322.41 56115135.82
# 2008/Mai              172402180.59      79268070.12 55574831.93
# 2008/Jun              175416595.83      79608652.53 56094754.74
#
# Unidade da Federação  43 Rio Grande do Sul  33 Rio de Janeiro    29 Bahia  \
# 2008/Fev                       45897704.82        44122593.19 33410124.06
# 2008/Mar                       52928695.92        42892665.52 41301703.40
# 2008/Abr                       51972416.77        45295962.86 42826993.62
# 2008/Mai                       51679350.79        43951349.46 42071294.17
# 2008/Jun                       53759674.01        44102925.77 39910042.40
#
# Unidade da Federação  26 Pernambuco  42 Santa Catarina    23 Ceará  \
# ...

# %%
ax = ordenado_total2.T[["35 São Paulo","31 Minas Gerais","41 Paraná","43 Rio Grande do Sul","33 Rio de Janeiro","28 Sergipe"]].plot(figsize = (16,9))
#ax = ordenado_total.T["28 Sergipe"].plot(figsize = (16,9))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.xlabel("Região do Brasil")
plt.ylabel("Gastos em R$")
plt.title("Estados com maior gasto Hospitalar e SERGIPE")

plt.show()
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
ax = ordenado_total2.T[["35 São Paulo","31 Minas Gerais","33 Rio de Janeiro","32 Espírito Santo"]].plot(figsize = (16,9))
#ax = ordenado_total.T["28 Sergipe"].plot(figsize = (16,9))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.xlabel("Região do Brasil")
plt.ylabel("Gastos em R$")
plt.title("Gastos hospitalares do Sudeste")

plt.show()
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# # Aula 04

# %%
ordenado_total3 = ordenado_total2 / 1000000
ax = ordenado_total3.T[["35 São Paulo","31 Minas Gerais","41 Paraná","43 Rio Grande do Sul","33 Rio de Janeiro","28 Sergipe"]].plot(figsize = (16,9))
#ax = ordenado_total.T["28 Sergipe"].plot(figsize = (16,9))

#ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.xlabel("Região do Brasil")
plt.ylabel("Gastos em milhões de R$")
plt.title("Estados com maior gasto Hospitalar e SERGIPE")

plt.show()
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
ordenado_total3.head(3).T.plot(figsize = (16,9))
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %%
# Aqui vou filtrar por coluna, ou seja a data, vou pegar da coluna 47 a 150 (Se lembre que ele so aplica a Transposição depois)
# Ou seja, as colunas continuam sendo as datas, e as linhas os estados, depois eu aplico o head(3) para pegar as 3 primeiras
# linhas, ou seja os 3 primeiros estados que mais gastam com hospital (Se lembre que o df ordenado total está em ordem de gasto)
# depois a gente faz a transposta da matriz, para que as colunas virem estados e a gente plote

ordenado_total3[ordenado_total3.columns[47:150]].head(3).T.plot(figsize = (16,9))
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %%
# Mudei o limite do eixo Y


ordenado_total3[ordenado_total3.columns[47:150]].head(3).T.plot(figsize = (16,9))
plt.ylim(0,350)
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# (0.0, 350.0)

# %%
# Diminuindo a Janela de tempo

ordenado_total3[ordenado_total3.columns[-12:]].head(3).T.plot(figsize = (16,9))
plt.ylim(0,350)
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# (0.0, 350.0)

# %%
# Diminuindo a Janela de tempo

ordenado_total3[ordenado_total3.columns[-24:]].head(3).T.plot(figsize = (16,9))
plt.ylim(0,350)
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# (0.0, 350.0)

# %%
# Diminuindo a Janela de tempo


ordenado_total3[ordenado_total3.columns[-36:]].head(3).T.plot(figsize = (16,9))
plt.ylim(0,350)
# Out:
# C:\Users\caiov\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# (0.0, 350.0)

# %% [markdown]
# ### Boas e más praticas
#
# #### Tomar cuidado com os eixos
# #### Tomar cuidado com o tamanho da figura
# #### Tomar cuidado com o range de valores que você pega, no nosso caso, o periodo de meses, ou o range de gastos
# #### Isso tudo citado, pode acabar gerando falsas informações, você vai estar omitindo fatos ou até inventando comportamentos que não existem nos dados

# %% [markdown]
# # Aula 05

# %%
# Como pegar o ultimo valor (Descobrir o ultimo mes)

mes_mais_recente = ordenado_total.columns[-1]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_do_mais_recente = ordenado_total3[mes_mais_recente]
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           282.71
# 31 Minas Gerais        120.47
# 41 Paraná               80.32
# 43 Rio Grande do Sul    78.93
# 33 Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             282.71
# 31 Minas Gerais          120.47
# 41 Paraná                 80.32
# 43 Rio Grande do Sul      78.93
# 33 Rio de Janeiro         71.54
# 26 Pernambuco             62.33
# 29 Bahia                  58.90
# 42 Santa Catarina         51.76
# 52 Goiás                  33.50
# 23 Ceará                  30.81
# 15 Pará                   27.62
# 32 Espírito Santo         27.46
# 21 Maranhão               24.37
# 53 Distrito Federal       22.23
# 24 Rio Grande do Norte    19.59
# 22 Piauí                  18.02
# 25 Paraíba                15.49
# 13 Amazonas               13.36
# 27 Alagoas                13.09
# 51 Mato Grosso            13.08
# 50 Mato Grosso do Sul     12.51
# 11 Rondônia                7.41
# 17 Tocantins               4.49
# 28 Sergipe                 3.31
# 14 Roraima                 2.74
# 16 Amapá                   2.16
# 12 Acre                    1.16
# Name: 2020/Jul, dtype: float64

# %%
# Grafico de pizza
# Legenda horrivel
# Numero de fatias inacreditavel (Tem muitos pedaços e a porcentagem fica estranha)
# Cores repetidas
# Muito ruim para definir ordem e para comparar
# Uma vantagem, é estar ordenado


gastos_do_mais_recente.plot(kind = 'pie',figsize = (16,9))
# Out:
# <AxesSubplot:ylabel='2020/Jul'>

# %%
# Eu fiz esse de barra so pra testar

gastos_do_mais_recente.plot(kind = 'bar',figsize = (16,9))
plt.title("Teste")
plt.xlabel("Estados")
plt.ylabel("Gastos em milhões de R$")
plt.grid()

# %% [markdown]
# # NOTA
# #### df["ASSIM"] ---> Ele pega por coluna
# #### df.loc["ASSIM"] ---> Ele pega por linha

# %%
# Olhar o quão mais ou menos de certo estado está sendo gasto
# São paulo gastou 85 vezes mais que sergipe
# Amapa gastou 65% que sergipe gastou
# Ele

gasto_recente_sergipe = gastos_do_mais_recente / gastos_do_mais_recente.loc["28 Sergipe"]
gasto_recente_sergipe
# Out:
# Unidade da Federação
# 35 São Paulo             85.34
# 31 Minas Gerais          36.36
# 41 Paraná                24.25
# 43 Rio Grande do Sul     23.83
# 33 Rio de Janeiro        21.60
# 26 Pernambuco            18.81
# 29 Bahia                 17.78
# 42 Santa Catarina        15.63
# 52 Goiás                 10.11
# 23 Ceará                  9.30
# 15 Pará                   8.34
# 32 Espírito Santo         8.29
# 21 Maranhão               7.36
# 53 Distrito Federal       6.71
# 24 Rio Grande do Norte    5.91
# 22 Piauí                  5.44
# 25 Paraíba                4.68
# 13 Amazonas               4.03
# 27 Alagoas                3.95
# 51 Mato Grosso            3.95
# 50 Mato Grosso do Sul     3.78
# 11 Rondônia               2.24
# 17 Tocantins              1.36
# 28 Sergipe                1.00
# 14 Roraima                0.83
# 16 Amapá                  0.65
# 12 Acre                   0.35
# Name: 2020/Jul, dtype: float64

# %%
# Eu fiz esse de barra so pra testar

gasto_recente_sergipe.plot(kind = 'bar',figsize = (16,9))
plt.title("Teste")
plt.xlabel("Estados")
plt.ylabel("Gastos em milhões de R$")
plt.grid()
